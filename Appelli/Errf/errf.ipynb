# %%
import numpy as np
import matplotlib.pyplot as plt
x = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
f = [-0.5, -0.443628, -0.387537, -0.332004, -0.277297, -0.223674, -0.171373, -0.120618, -0.0716076, -0.0245183, 0.0204999, 0.0633234, 0.103856, 0.142029, 0.177801, 0.211156, 0.242101, 0.270668, 0.296908, 0.320891]
plt.plot(x, f, color = 'r')
