# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
x = np.ndarray((24), dtype = np.double)
xteo = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)
yteo = np.ndarray((24), dtype = np.double)
vx = np.ndarray((24), dtype = np.double)
vy = np.ndarray((24), dtype = np.double)
xerr = np.ndarray((24), dtype = np.double)
yerr = np.ndarray((24), dtype = np.double)

t, x, xteo, y, yteo, vx, vy, xerr, yerr = np.loadtxt("dati1.txt", unpack = True)
plt.plot(x,y, color = 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
x = np.ndarray((24), dtype = np.double)
xteo = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)
yteo = np.ndarray((24), dtype = np.double)
vx = np.ndarray((24), dtype = np.double)
vy = np.ndarray((24), dtype = np.double)
xerr = np.ndarray((24), dtype = np.double)
yerr = np.ndarray((24), dtype = np.double)

t, x, xteo, y, yteo, vx, vy, xerr, yerr = np.loadtxt("dati10.txt", unpack = True)
plt.plot(x,y, color = 'r')

# %%
angolo = [ 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05, 1.2, 1.35, 1.5 ]
gittata = [ 191.69, 252.43, 265.887, 256.356, 233.222, 200.961, 162.164, 118.648, 71.8942, 23.2475 ]
plt.plot(angolo, gittata, color = 'r')
