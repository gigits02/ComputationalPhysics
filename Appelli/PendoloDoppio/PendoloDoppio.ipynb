# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
vth = np.ndarray((24), dtype = np.double)
T = np.ndarray((24), dtype = np.double)

t, th, vth, T = np.loadtxt("dati1.txt", unpack = True)
plt.plot(t, th, color = 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
vth = np.ndarray((24), dtype = np.double)
T = np.ndarray((24), dtype = np.double)

t, th, vth, T = np.loadtxt("dati2.txt", unpack = True)
plt.plot(t, T, color = 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
vth = np.ndarray((24), dtype = np.double)
T = np.ndarray((24), dtype = np.double)

t, th, vth, T = np.loadtxt("dati3.txt", unpack = True)
plt.plot(t, th, color = 'r')
