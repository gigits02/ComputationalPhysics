# %%
import numpy as np
import matplotlib.pyplot as plt
e = [0, 0.1, 0.2, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
l = [6.28319, 6.26745, 6.21987, 6.02377, 5.86985, 5.67233, 5.42264, 5.1054, 4.68679, 4]
plt.plot(e, l, color = 'r')
