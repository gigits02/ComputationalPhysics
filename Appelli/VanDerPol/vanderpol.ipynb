# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
x = np.ndarray((24), dtype = np.double)
vx = np.ndarray((24), dtype = np.double)


t, x, vx = np.loadtxt("dati1.txt", unpack = True)
plt.plot(t, x, color = 'r')

# %%
t, x, vx = np.loadtxt("dati2.txt", unpack = True)
plt.plot(t, x, color = 'r')

# %%
t, x, vx = np.loadtxt("dati3.txt", unpack = True)
plt.plot(t, x, color = 'r')
