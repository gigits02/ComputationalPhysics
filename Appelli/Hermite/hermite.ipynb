# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)
t, y = np.loadtxt("dati0.txt", unpack = True)
plt.plot(t, y, color = 'r')
