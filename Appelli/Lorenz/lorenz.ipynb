# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
x1 = np.ndarray((24), dtype = np.double)
y1 = np.ndarray((24), dtype = np.double)
z1 = np.ndarray((24), dtype = np.double)
t, x1, y1, z1 = np.loadtxt("dati1.txt", unpack = True)
plt.plot(t, x1, color = 'r')
plt.plot(t, y1, color = 'b')
plt.plot(t, z1, color = 'g')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
x2 = np.ndarray((24), dtype = np.double)
y2 = np.ndarray((24), dtype = np.double)
z2 = np.ndarray((24), dtype = np.double)
t, x2, y2, z2 = np.loadtxt("dati2.txt", unpack = True)
plt.plot(t, x2, color = 'r')
plt.plot(t, y2, color = 'b')
plt.plot(t, z2, color = 'g')

# %%
plt.plot(x1, y1, color = 'r')
plt.plot(x1, z1, color = 'b')
plt.plot(y1, z1, color = 'g')

# %%
plt.plot(x2, y2, color = 'r')
plt.plot(x2, z2, color = 'b')
plt.plot(y2, z2, color = 'g')
