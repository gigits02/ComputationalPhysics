# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)
yex = np.ndarray((24), dtype = np.double)
err = np.ndarray((24), dtype = np.double)
x, y, yex, err = np.loadtxt("dati4.txt", unpack = True)
plt.plot(x,y, color = 'r')
plt.plot(x, yex, color = 'b')
