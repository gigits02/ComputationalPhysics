# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
theta = np.ndarray((24), dtype = np.double)
v_theta = np.ndarray((24), dtype = np.double)
R_x = np.ndarray((24), dtype = np.double)
R_y = np.ndarray((24), dtype = np.double)
t, theta, v_theta, R_x, R_y = np.loadtxt("dati.txt", unpack = True)
plt.plot(t,theta, color = 'r')
