# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
r = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
z = np.ndarray((24), dtype = np.double)
x = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)

t, r, th, z, x, y = np.loadtxt("dati1.txt", unpack = True)
plt.plot(t, z, color = 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
r = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
z = np.ndarray((24), dtype = np.double)
x = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)

t, r, th, z, x, y = np.loadtxt("dati1.txt", unpack = True)
plt.plot(x, y, color = 'r')
