# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
I = np.ndarray((24), dtype = np.double)
V = np.ndarray((24), dtype = np.double)

t, I, V = np.loadtxt("datisotto.txt", unpack = True)
plt.plot(t, I, color = 'r')

# %%
t, I, V = np.loadtxt("datisovra.txt", unpack = True)
plt.plot(t, I, color = 'r')

# %%
t, I, V = np.loadtxt("daticrit.txt", unpack = True)
plt.plot(t, I, color = 'r')

# %%
t, I, V = np.loadtxt("w1.txt", unpack = True)
plt.plot(t, I, color = 'r')

# %%
w = [0.1, 0.5, 1.4, 1.8, 2.2]
I = [4.9e-05, 0.000223, 0.000419, 0.000457, 0.000483]
plt.plot(w,I)
