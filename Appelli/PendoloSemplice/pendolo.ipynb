# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
th = np.ndarray((24), dtype = np.double)
vth = np.ndarray((24), dtype = np.double)

t, th, vth = np.loadtxt("dati.txt", unpack = True)
plt.plot(t, th, color = 'r')

# %%
import matplotlib.pyplot as plt
x = [0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.0010, 0.0011, 0.0012, 0.0013]
y = [0.006, 0.007,0.008,0.009, 0.01, 0.011,0.012, 0.013, 0.014]

plt.plot(x,y)
