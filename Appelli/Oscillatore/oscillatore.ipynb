# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.ndarray((24), dtype = np.double)
y = np.ndarray((24), dtype = np.double)
vy = np.ndarray((24), dtype = np.double)
err = np.ndarray((24), dtype = np.double)

t, y, vy, err = np.loadtxt("dati1.txt", unpack = True)
plt.plot(t, y, color = 'r')

# %%
eps = [6.20830830320995e-10, 4.96658660031901e-09, 1.67618920080687e-08,  3.97307712701744e-08, 7.7596347951292e-08 ]
w = [1,2,3,4,5]
plt.plot(w,eps)

# %%
a = 4.96658660031901e-09/8
b = 1.67618920080687e-08/27
c = 3.97307712701744e-08/(4*4*4)
d = 7.7596347951292e-08/(5*5*5)
print(a) 
print(b)
print(c)
print(d)
# Out:
# 6.208233250398763e-10
# 6.208108151136556e-10
# 6.20793301096475e-10
# 6.20770783610336e-10
