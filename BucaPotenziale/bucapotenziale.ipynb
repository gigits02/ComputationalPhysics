# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.ndarray((24), dtype = np.double)
ph = np.ndarray((24), dtype = np.double)
phteo = np.ndarray((24), dtype = np.double)
err = np.ndarray((24), dtype = np.double)

x, ph, phteo, err = np.loadtxt("dati1.txt", unpack = True)
plt.plot(x, ph, color = 'r')
